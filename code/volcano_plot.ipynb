# %%
library(EnhancedVolcano)
# Out:
# Loading required package: ggplot2
#
# Loading required package: ggrepel

# %%
DA_peaks <- read.csv('/Users/minjunp/Documents/baylor/hali/differential_test/DA/da_cm_peaks.csv')

# %%
rownames(DA_peaks) <- DA_peaks[,1]
DA_peaks[,1] <- NULL

# %%
head(DA_peaks)
# Out:
#                          p_val avg_logFC  pct.1 pct.2 p_val_adj
# chr1-135798446-135802897 0      0.5702725 0.506 0.218 0
# chr5-122444155-122504095 0     -0.2559584 0.936 0.965 0
# chr9-48727595-48742017   0     -0.3147778 0.470 0.737 0
# chr8-121561565-121564350 0     -0.5212949 0.196 0.499 0
# chr4-137767530-137773083 0     -0.5681052 0.168 0.510 0
# chr5-121998373-122001144 0     -0.6117293 0.157 0.459 0

# %%
vol <- EnhancedVolcano(DA_peaks,
    lab = rownames(DA_peaks),
    x = 'avg_logFC',
    y = 'p_val_adj',
    title = 'Whole Heart Cardiomyocytes DA peaks',
    pCutoff = 10e-100,
    FCcutoff = 0.5,
    pointSize = 2.0)
    #labSize = 5.0)
# Out:
# Warning message:
# “One or more p-values is 0. Converting to 10^-1 * current lowest non-zero p-value...”

# %%
vol
# Out:
# plot without title

# %%
pdf("da_cm_volcano.pdf", useDingbats=FALSE)
vol
dev.off()
# Out:
# pdf
#   2
